# %%
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search

es_client = Elasticsearch(http_compress=True)

# %%
def last_case_generator(type, year):
    s = Search(using=es_client, index="case").filter('term',type=type).filter('term',year=year)
    s.aggs.bucket('per_county','terms', size=100, field='county').metric('last_case','max',field='number')
    response = s.execute()

    for county in response.aggregations.per_county.buckets: 
        yield (county.key, int(county.last_case.value))
    raise StopIteration

# %%
from datetime import datetime
from elasticsearch import helpers
import oscn


keys = [ 
        'county',
        'year',
        'type', 
        'number',
        'filed',
        'closed', 
        'offense',
        'parties',
        'issues',
        'counts',
        'docket',
        'source']

def safe_date(date_str):
    return datetime.strptime(date_str, '%m/%d/%Y') if date_str else datetime(1970,1,1,0,0)

def case_values(c):
    return [ 
            c.county,
            c.year,
            c.type, 
            c.number, 
            safe_date(c.filed),  
            safe_date(c.closed),  
            safe_date(c.offense),  
            c.parties, 
            c.issues, 
            c.counts, 
            c.docket, 
            c.source]

def lists2dict(keys, values):
    safe_values  = map(lambda v: v if v else [], values)
    return {k: v for k, v in map(lambda k, v: (k, v), keys, safe_values)}



def doc_generator(year, county, case_type, start):
    case_list = oscn.request.CaseList(year=year, county=county, type=case_type, start=start, stop=70)
    for case in case_list:
        
#         for idx, party in enumerate(case.parties):
#             yield {
#                     "_index": 'party',
#                     "_type": "_doc",
#                     "_id" : f"{case.case_index}-{idx}",
#                     "_source": party,
#                     "parent": case.case_index,
#                 }
            
#         if case.issues:
#             for idx, issue in enumerate(case.issues):
#                 issue_index = f"{case.case_index}-{idx}"
#                 yield {
#                     "_index": 'issue',
#                     "_type": "_doc",
#                     "_id" : issue_index,
#                     "_source": issue,
#                     "parent": case.case_index,

#                 }
#                 if issue['dispositions']:
#                     for idx, disposition in enumerate(issue['dispositions']):
#                         yield {
#                             "_index": 'disposition',
#                             "_type": "_doc",
#                             "_id" : f"{case.case_index}-{idx}",
#                             "_source": disposition,
#                             "parent": issue_index,
#                         }
#         if case.counts:
#             for idx, count in enumerate(case.counts):
#                 yield {
#                         "_index": 'counts',
#                         "_type": "_doc",
#                         "_id" : f"{case.case_index}-{idx}",
#                         "_source": count,
#                         "parent": case.case_index,
#                     }

#         for ids, minute in enumerate(case.docket):
            
#             yield {
#                     "_index": 'minute',
#                     "_type": "_doc",
#                     "_id" : f"{case.case_index}-{idx}",
#                     "_source": minute,
#                     "parent": case.case_index,
#                 }
        
        yield {
                "_index": 'case',
                "_type": "_doc",
                "_id" : f"{case.case_index}",
                "_source": lists2dict(keys, case_values(case)),
            }
    raise StopIteration

# %% [markdown]
# ## Get new cases

# %%
years = ['2019']
counties = ['tulsa']
types = ['CV', 'PB', 'FD','CF','CM']


for year in years:
    for case_type in types:
        for county, last in last_case_generator(case_type,year):
            print(f'county:{county} last:{last}')
            start = last + 1
            helpers.bulk(es_client, doc_generator(year, county, case_type, start))
# Out:
# county:tulsa last:70
# county:tulsa last:56
# county:tulsa last:70
# county:tulsa last:70
# county:tulsa last:70

# %% [markdown]
# ## All Cases

# %%
import oscn

years = ['2019']
counties = ['tulsa']
# counties = oscn.counties
types = ['CV', 'PB', 'FD','CF','CM']


for year in years:
    for case_type in types:
        for county in counties:
            print(f'year:{year} type:{case_type} county:{county}')
            helpers.bulk(es_client, doc_generator(year, county, case_type, 1))
# Out:
# year:2019 type:CV county:tulsa
# year:2019 type:PB county:tulsa
# year:2019 type:FD county:tulsa
# year:2019 type:CF county:tulsa
# year:2019 type:CM county:tulsa

# %%
c=oscn.request.Case(type='CV')

# %%
lists2dict(keys, case_values(c))
# Out:
# {'id': 'tulsa-CV-2018-1',
#  'county': 'tulsa',
#  'year': '2018',
#  'type': 'CV',
#  'number': 1,
#  'filed': datetime.datetime(2018, 1, 2, 0, 0),
#  'closed': datetime.datetime(2018, 6, 15, 0, 0),
#  'offense': datetime.datetime(1970, 1, 1, 0, 0),
#  'parties': [{'name': 'CRADDOCK, D S', 'type': 'Deceased'},
#   {'name': 'SPRINGER, LESTER', 'type': 'Plaintiff'},
#   {'name': 'STONE, EVELYN J', 'type': 'Defendant'}],
#  'issues': [{'Filed Date': '01/02/2018',
#    'Filed By': 'SPRINGER, LESTER',
#    'Issue': 'QUIET TITLE (QUIET)',
#    'dispositions': [{'Defendant': 'STONE, EVELYN J',
#      'Respondent': '',
#      'Disposed': 'JUDGEMENT ENTERED, 06/15/2018. Other'}]}],
#  'counts': 'None',
#  'docket': [{'date': '01-02-2018',
#    'code': 'TEXT',
#    'description': 'CIVIL MISC. INITIAL FILING.',
#    'count': '1',
#    'party': '',
#    'amount': ''},
#   {'date': '01-02-2018',
#    'code': 'QUIET',
#    'description': 'QUIET TITLE',
#    'count': '',
#    'party': '',
#    'amount': ''},
#   {'date': '01-02-2018',
#    'code': 'DMFE',
#    'description': 'DISPUTE MEDIATION FEE',
#    'count': '',
#    'party': '',
#    'amount': '$ 7.00'},
#   {'date': '01-02-2018',
#    'code': 'PFE1',
#    'description': 'PETITION Document Available (#1039086597) TIFF PDF',
#    'count': '',
#    'party': '',
#    'amount': '$ 85.00'},
#   {'date': '01-02-2018',
#    'code': 'PFE7',
#    'description': 'LAW LIBRARY FEE',
#    'count': '',
#    'party': '',
#    'amount': '$ 6.00'},
#   {'date': '01-02-2018',
#    'code': 'OCISR',
#    'description': 'OKLAHOMA COURT INFORMATION SYSTEM REVOLVING FUND',
#    'count': '',
#    'party': '',
#    'amount': '$ 25.00'},
#   {'date': '01-02-2018',
#    'code': 'OCJC',
#    'description': 'OKLAHOMA COUNCIL ON JUDICIAL COMPLAINTS REVOLVING FUND',
#    'count': '',
#    'party': '',
#    'amount': '$ 1.55'},
#   {'date': '01-02-2018',
#    'code': 'OCASA',
#    'description': 'OKLAHOMA COURT APPOINTED SPECIAL ADVOCATES',
#    'count': '',
#    'party': '',
#    'amount': '$ 5.00'},
#   {'date': '01-02-2018',
#    'code': 'SSFCHSCPC',
#    'description': "SHERIFF'S SERVICE FEE FOR COURTHOUSE SECURITY PER BOARD OF COUNTY COMMISSIONER",
#    'count': '',
#    'party': '',
#    'amount': '$ 10.00'},
#   {'date': '01-02-2018',
#    'code': 'CCADMINCSF',
#    'description': 'COURT CLERK ADMINISTRATIVE FEE ON COURTHOUSE SECURITY PER BOARD OF COUNTY COMMISSIONER',
#    'count': '',
#    'party': '',
#    'amount': '$ 1.00'},
#   {'date': '01-02-2018',
#    'code': 'CCADMIN0155',
#    'description': 'COURT CLERK ADMINISTRATIVE FEE ON $1.55 COLLECTION',
#    'count': '',
#    'party': '',
#    'amount': '$ 0.16'},
#   {'date': '01-02-2018',
#    'code': 'SJFIS',
#    'description': 'STATE JUDICIAL REVOLVING FUND - INTERPRETER AND TRANSLATOR SERVICES',
#    'count': '',
#    'party': '',
#    'amount': '$ 0.45'},
#   {'date': '01-02-2018',
#    'code': 'DCADMIN155',
#    'description': 'DISTRICT COURT ADMINISTRATIVE FEE ON $1.55 COLLECTIONS',
#    'count': '',
#    'party': '',
#    'amount': '$ 0.23'},
#   {'date': '01-02-2018',
#    'code': 'DCADMIN05',
#    'description': 'DISTRICT COURT ADMINISTRATIVE FEE ON $5 COLLECTIONS',
#    'count': '',
#    'party': '',
#    'amount': '$ 0.75'},
#   {'date': '01-02-2018',
#    'code': 'DCADMINCSF',
#    'description': 'DISTRICT COURT ADMINISTRATIVE FEE ON COURTHOUSE SECURITY PER BOARD OF COUNTY COMMISSIONER',
#    'count': '',
#    'party': '',
#    'amount': '$ 1.50'},
#   {'date': '01-02-2018',
#    'code': 'CCADMIN04',
#    'description': 'COURT CLERK ADMINISTRATIVE FEE ON COLLECTIONS',
#    'count': '',
#    'party': '',
#    'amount': '$ 0.50'},
#   {'date': '01-02-2018',
#    'code': 'LTF',
#    'description': 'LENGTHY TRIAL FUND',
#    'count': '',
#    'party': '',
#    'amount': '$ 10.00'},
#   {'date': '01-02-2018',
#    'code': 'TEXT',
#    'description': 'OCIS HAS AUTOMATICALLY ASSIGNED JUDGE WALL, CAROLINE TO THIS CASE.',
#    'count': '',
#    'party': '',
#    'amount': ''},
#   {'date': '01-02-2018',
#    'code': 'ACCOUNT',
#    'description': 'RECEIPT # 2018-3689404 ON 01/02/2018. PAYOR: MORGAN K POWELL TOTAL AMOUNT PAID: $ 154.14. LINE ITEMS: CV-2018-1: $85.00 ON AC01 CLERK FEES. CV-2018-1: $6.00 ON AC23 LAW LIBRARY FEE CIVIL AND CRIMINAL. CV-2018-1: $1.66 ON AC31 COURT CLERK REVOLVING FUND. CV-2018-1: $5.00 ON AC58 OKLAHOMA COURT APPOINTED SPECIAL ADVOCATES. CV-2018-1: $1.55 ON AC59 COUNCIL ON JUDICIAL COMPLAINTS REVOLVING FUND. CV-2018-1: $7.00 ON AC64 DISPUTE MEDIATION FEES CIVIL ONLY. CV-2018-1: $0.45 ON AC65 STATE JUDICIAL REVOLVING FUND, INTERPRETER SVCS. CV-2018-1: $2.48 ON AC67 DISTRICT COURT REVOLVING FUND. CV-2018-1: $25.00 ON AC79 OCIS REVOLVING FUND. CV-2018-1: $10.00 ON AC81 LENGTHY TRIAL FUND. CV-2018-1: $10.00 ON AC88 SHERIFF’S SERVICE FEE FOR COURT HOUSE SECURITY.',
#    'count': '',
#    'party': '',
#    'amount': ''},
#   {'date': '02-13-2018',
#    'code': 'NO',
#    'description': 'NOTICE OF PUBLICATION Document Available (#1039617828) TIFF PDF',
#    'count': '',
#    'party': 'SPRINGER, LESTER',
#    'amount': ''},
#   {'date': '03-12-2018',
#    'code': 'PP',
#    'description': 'PROOF OF PUBLICATION (OK WKLY GRP) Document Available (#1039613752) TIFF PDF',
#    'count': '',
#    'party': '',
#    'amount': ''},
#   {'date': '03-12-2018',
#    'code': 'S',
#    'description': 'CLERKS NOTE: THIS IS NOT AN INSTRUMENT - THIS IS TO SHOW SERVICE ON: EVELYN J STONE IF LIVING/DECEASED ANY HEIRS/ASSIGNS',
#    'count': '',
#    'party': 'STONE, EVELYN J',
#    'amount': ''},
#   {'date': '03-12-2018',
#    'code': 'S',
#    'description': 'CLERKS NOTE: THIS IS NOT AN INSTRUMENT - THIS IS TO SHOW SERVICE ON: D S CRADDOCK DECEASED ANY HEIRS/ASSIGNS',
#    'count': '',
#    'party': 'CRADDOCK, D S',
#    'amount': ''},
#   {'date': '06-06-2018',
#    'code': 'ANMS',
#    'description': 'AFFIDAVIT TO MILITARY SERVICE Document Available (#1040568104) TIFF PDF',
#    'count': '',
#    'party': 'SPRINGER, LESTER',
#    'amount': ''},
#   {'date': '06-06-2018',
#    'code': 'TEXT',
#    'description': 'AFFIDAVIT IN SUPPORT OF NOTICE BY PUBLICATION Document Available (#1040568100) TIFF PDF',
#    'count': '',
#    'party': 'SPRINGER, LESTER',
#    'amount': ''},
#   {'date': '06-06-2018',
#    'code': 'ANM',
#    'description': 'AFFIDAVIT OF NON-MAILING Document Available (#1040568192) TIFF PDF',
#    'count': '',
#    'party': 'SPRINGER, LESTER',
#    'amount': ''},
#   {'date': '06-06-2018',
#    'code': 'TEXT',
#    'description': 'EVIDENTIARY AFFIDAVIT OF BONDED ABSTRACTOR Document Available (#1040568096) TIFF PDF',
#    'count': '',
#    'party': 'SPRINGER, LESTER',
#    'amount': ''},
#   {'date': '06-06-2018',
#    'code': 'DISCL',
#    'description': 'DISCLAIMER OF INTEREST IN REAL PROPERTY ( DONNA J SMOCK- HEIR OF EVELYN J STONE ) Document Available (#1040568092) TIFF PDF',
#    'count': '',
#    'party': '',
#    'amount': ''},
#   {'date': '06-15-2018',
#    'code': 'DISPJE',
#    'description': 'WALL, CAROLINE; GRANTED/JOURNAL ENTRY OF JUDGMENT;',
#    'count': '1',
#    'party': 'STONE, EVELYN J',
#    'amount': ''},
#   {'date': '06-20-2018',
#    'code': 'JEJ',
#    'description': 'JOURNAL ENTRY OF JUDGMENT QUIETING TITLE Document Available (#1040708778) TIFF PDF',
#    'count': '',
#    'party': 'STONE, EVELYN J',
#    'amount': ''}],
#  'source': 'https://www.oscn.net/dockets/GetCaseInformation.aspx?db=tulsa&number=CV-2018-1'}
